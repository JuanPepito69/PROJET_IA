# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanPepito69/PROJET_IA/blob/main/project_IA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Récupération et nettoyage préliminaire des données "train" :

train1 = pd.read_csv('train_FD001.csv')
train1.info()
train2 = pd.read_csv('train_FD002.csv')
train2.info()
train3 = pd.read_csv('train_FD003.csv')
train3.info()
train4 = pd.read_csv('train_FD004.csv')
train4.info()

train1 = train1.drop_duplicates()
train1 = train1.dropna()
train2 = train2.drop_duplicates()
train2 = train2.dropna()
train3 = train3.drop_duplicates()
train3 = train3.dropna()
train4 = train4.drop_duplicates()
train4 = train4.dropna()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20631 entries, 0 to 20630
# Data columns (total 26 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          20631 non-null  int64
#  1   Parameter1  20631 non-null  float64
#  2   Parameter2  20631 non-null  float64
#  3   Parameter3  20631 non-null  float64
#  4   Sensor1     20631 non-null  float64
#  5   Sensor2     20631 non-null  float64
#  6   Sensor3     20631 non-null  float64
#  7   Sensor4     20631 non-null  float64
#  8   Sensor5     20631 non-null  float64
#  9   Sensor6     20631 non-null  float64
#  10  Sensor7     20631 non-null  float64
#  11  Sensor8     20631 non-null  float64
#  12  Sensor9     20631 non-null  float64
#  13  Sensor10    20631 non-null  float64
#  14  Sensor11    20631 non-null  float64
#  15  Sensor12    20631 non-null  float64
#  16  Sensor13    20631 non-null  float64
#  17  Sensor14    20631 non-null  float64
#  18  Sensor15    20631 non-null  float64
#  19  Sensor16    20631 non-null  float64
#  20  Sensor17    20631 non-null  int64
#  21  Sensor18    20631 non-null  int64
#  22  Sensor19    20631 non-null  float64
#  23  Sensor20    20631 non-null  float64
#  24  Sensor21    20631 non-null  float64
#  25  RUL         20631 non-null  int64
# dtypes: float64(22), int64(4)
# memory usage: 4.1 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53759 entries, 0 to 53758
# Data columns (total 26 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          53759 non-null  int64
#  1   Parameter1  53759 non-null  float64
#  2   Parameter2  53759 non-null  float64
#  3   Parameter3  53759 non-null  float64
#  4   Sensor1     53759 non-null  float64
#  5   Sensor2     53759 non-null  float64
#  6   Sensor3     53759 non-null  float64
#  7   Sensor4     53759 non-null  float64
#  8   Sensor5     53759 non-null  float64
#  9   Sensor6     53759 non-null  float64
#  10  Sensor7     53759 non-null  float64
#  11  Sensor8     53759 non-null  float64
#  12  Sensor9     53759 non-null  float64
#  13  Sensor10    53759 non-null  float64
#  14  Sensor11    53759 non-null  float64
#  15  Sensor12    53759 non-null  float64
#  16  Sensor13    53759 non-null  float64
#  17  Sensor14    53759 non-null  float64
#  18  Sensor15    53759 non-null  float64
#  19  Sensor16    53759 non-null  float64
#  20  Sensor17    53759 non-null  int64
#  21  Sensor18    53759 non-null  int64
#  22  Sensor19    53759 non-null  float64
#  23  Sensor20    53759 non-null  float64
#  24  Sensor21    53759 non-null  float64
#  25  RUL         53759 non-null  int64
# dtypes: float64(22), int64(4)
# memory usage: 10.7 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24720 entries, 0 to 24719
# Data columns (total 26 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          24720 non-null  int64
#  1   Parameter1  24720 non-null  float64
#  2   Parameter2  24720 non-null  float64
#  3   Parameter3  24720 non-null  float64
#  4   Sensor1     24720 non-null  float64
#  5   Sensor2     24720 non-null  float64
#  6   Sensor3     24720 non-null  float64
#  7   Sensor4     24720 non-null  float64
#  8   Sensor5     24720 non-null  float64
#  9   Sensor6     24720 non-null  float64
#  10  Sensor7     24720 non-null  float64
#  11  Sensor8     24720 non-null  float64
#  12  Sensor9     24720 non-null  float64
#  13  Sensor10    24720 non-null  float64
#  14  Sensor11    24720 non-null  float64
#  15  Sensor12    24720 non-null  float64
#  16  Sensor13    24720 non-null  float64
#  17  Sensor14    24720 non-null  float64
#  18  Sensor15    24720 non-null  float64
#  19  Sensor16    24720 non-null  float64
#  20  Sensor17    24720 non-null  int64
#  21  Sensor18    24720 non-null  int64
#  22  Sensor19    24720 non-null  float64
#  23  Sensor20    24720 non-null  float64
#  24  Sensor21    24720 non-null  float64
#  25  RUL         24720 non-null  int64
# dtypes: float64(22), int64(4)
# memory usage: 4.9 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61249 entries, 0 to 61248
# Data columns (total 26 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          61249 non-null  int64
#  1   Parameter1  61249 non-null  float64
#  2   Parameter2  61249 non-null  float64
#  3   Parameter3  61249 non-null  float64
#  4   Sensor1     61249 non-null  float64
#  5   Sensor2     61249 non-null  float64
#  6   Sensor3     61249 non-null  float64
#  7   Sensor4     61249 non-null  float64
#  8   Sensor5     61249 non-null  float64
#  9   Sensor6     61249 non-null  float64
#  10  Sensor7     61249 non-null  float64
#  11  Sensor8     61249 non-null  float64
#  12  Sensor9     61249 non-null  float64
#  13  Sensor10    61249 non-null  float64
#  14  Sensor11    61249 non-null  float64
#  15  Sensor12    61249 non-null  float64
#  16  Sensor13    61249 non-null  float64
#  17  Sensor14    61249 non-null  float64
#  18  Sensor15    61249 non-null  float64
#  19  Sensor16    61249 non-null  float64
#  20  Sensor17    61249 non-null  int64
#  21  Sensor18    61249 non-null  int64
#  22  Sensor19    61249 non-null  float64
#  23  Sensor20    61249 non-null  float64
#  24  Sensor21    61249 non-null  float64
#  25  RUL         61249 non-null  int64
# dtypes: float64(22), int64(4)
# memory usage: 12.1 MB

# %%
#Récupération et nettoyage préliminaire des données "test" :

test1 = pd.read_csv('test_FD001.csv')
test1.info()
test2 = pd.read_csv('test_FD002.csv')
test2.info()
test3 = pd.read_csv('test_FD003.csv')
test3.info()
test4 = pd.read_csv('test_FD004.csv')
test4.info()

test1 = test1.drop_duplicates()
test1 = test1.dropna()
test2 = test2.drop_duplicates()
test2 = test2.dropna()
test3 = test3.drop_duplicates()
test3 = test3.dropna()
test4 = test4.drop_duplicates()
test4 = test4.dropna()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13096 entries, 0 to 13095
# Data columns (total 26 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          13096 non-null  int64
#  1   Parameter1  13096 non-null  float64
#  2   Parameter2  13096 non-null  float64
#  3   Parameter3  13096 non-null  float64
#  4   Sensor1     13096 non-null  float64
#  5   Sensor2     13096 non-null  float64
#  6   Sensor3     13096 non-null  float64
#  7   Sensor4     13096 non-null  float64
#  8   Sensor5     13096 non-null  float64
#  9   Sensor6     13096 non-null  float64
#  10  Sensor7     13096 non-null  float64
#  11  Sensor8     13096 non-null  float64
#  12  Sensor9     13096 non-null  float64
#  13  Sensor10    13096 non-null  float64
#  14  Sensor11    13096 non-null  float64
#  15  Sensor12    13096 non-null  float64
#  16  Sensor13    13096 non-null  float64
#  17  Sensor14    13096 non-null  float64
#  18  Sensor15    13096 non-null  float64
#  19  Sensor16    13096 non-null  float64
#  20  Sensor17    13096 non-null  int64
#  21  Sensor18    13096 non-null  int64
#  22  Sensor19    13096 non-null  float64
#  23  Sensor20    13096 non-null  float64
#  24  Sensor21    13096 non-null  float64
#  25  RUL         13096 non-null  int64
# dtypes: float64(22), int64(4)
# memory usage: 2.6 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33991 entries, 0 to 33990
# Data columns (total 26 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          33991 non-null  int64
#  1   Parameter1  33991 non-null  float64
#  2   Parameter2  33991 non-null  float64
#  3   Parameter3  33991 non-null  float64
#  4   Sensor1     33991 non-null  float64
#  5   Sensor2     33991 non-null  float64
#  6   Sensor3     33991 non-null  float64
#  7   Sensor4     33991 non-null  float64
#  8   Sensor5     33991 non-null  float64
#  9   Sensor6     33991 non-null  float64
#  10  Sensor7     33991 non-null  float64
#  11  Sensor8     33991 non-null  float64
#  12  Sensor9     33991 non-null  float64
#  13  Sensor10    33991 non-null  float64
#  14  Sensor11    33991 non-null  float64
#  15  Sensor12    33991 non-null  float64
#  16  Sensor13    33991 non-null  float64
#  17  Sensor14    33991 non-null  float64
#  18  Sensor15    33991 non-null  float64
#  19  Sensor16    33991 non-null  float64
#  20  Sensor17    33991 non-null  int64
#  21  Sensor18    33991 non-null  int64
#  22  Sensor19    33991 non-null  float64
#  23  Sensor20    33991 non-null  float64
#  24  Sensor21    33991 non-null  float64
#  25  RUL         33991 non-null  int64
# dtypes: float64(22), int64(4)
# memory usage: 6.7 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16596 entries, 0 to 16595
# Data columns (total 26 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          16596 non-null  int64
#  1   Parameter1  16596 non-null  float64
#  2   Parameter2  16596 non-null  float64
#  3   Parameter3  16596 non-null  float64
#  4   Sensor1     16596 non-null  float64
#  5   Sensor2     16596 non-null  float64
#  6   Sensor3     16596 non-null  float64
#  7   Sensor4     16596 non-null  float64
#  8   Sensor5     16596 non-null  float64
#  9   Sensor6     16596 non-null  float64
#  10  Sensor7     16596 non-null  float64
#  11  Sensor8     16596 non-null  float64
#  12  Sensor9     16596 non-null  float64
#  13  Sensor10    16596 non-null  float64
#  14  Sensor11    16596 non-null  float64
#  15  Sensor12    16596 non-null  float64
#  16  Sensor13    16596 non-null  float64
#  17  Sensor14    16596 non-null  float64
#  18  Sensor15    16596 non-null  float64
#  19  Sensor16    16596 non-null  float64
#  20  Sensor17    16596 non-null  int64
#  21  Sensor18    16596 non-null  int64
#  22  Sensor19    16596 non-null  float64
#  23  Sensor20    16596 non-null  float64
#  24  Sensor21    16596 non-null  float64
#  25  RUL         16596 non-null  int64
# dtypes: float64(22), int64(4)
# memory usage: 3.3 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41214 entries, 0 to 41213
# Data columns (total 26 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          41214 non-null  int64
#  1   Parameter1  41214 non-null  float64
#  2   Parameter2  41214 non-null  float64
#  3   Parameter3  41214 non-null  float64
#  4   Sensor1     41214 non-null  float64
#  5   Sensor2     41214 non-null  float64
#  6   Sensor3     41214 non-null  float64
#  7   Sensor4     41214 non-null  float64
#  8   Sensor5     41214 non-null  float64
#  9   Sensor6     41214 non-null  float64
#  10  Sensor7     41214 non-null  float64
#  11  Sensor8     41214 non-null  float64
#  12  Sensor9     41214 non-null  float64
#  13  Sensor10    41214 non-null  float64
#  14  Sensor11    41214 non-null  float64
#  15  Sensor12    41214 non-null  float64
#  16  Sensor13    41214 non-null  float64
#  17  Sensor14    41214 non-null  float64
#  18  Sensor15    41214 non-null  float64
#  19  Sensor16    41214 non-null  float64
#  20  Sensor17    41214 non-null  int64
#  21  Sensor18    41214 non-null  int64
#  22  Sensor19    41214 non-null  float64
#  23  Sensor20    41214 non-null  float64
#  24  Sensor21    41214 non-null  float64
#  25  RUL         41214 non-null  int64
# dtypes: float64(22), int64(4)
# memory usage: 8.2 MB

# %%
#Concaténation et renettoyage de toutes les données :
DATAS = pd.concat([train1.iloc[:, 1:],
                     train2.iloc[:, 1:],
                     train3.iloc[:, 1:],
                     train4.iloc[:, 1:],
                     test1.iloc[:, 1:],
                     test2.iloc[:, 1:],
                     test3.iloc[:, 1:],
                     test4.iloc[:, 1:]], axis=0)
DATAS = DATAS.drop_duplicates()
DATAS = DATAS.dropna()
DATAS.columns = ["Parameter 1",
                 "Parameter 2",
                 "Parameter 3",
                 "T° tot fan inlet [°R]",
                 "T LPC outlet [°R]",
                 "T HPC outlet [°R]",
                 "T LPT outlet [°R]",
                 "P fan inlet [psia]",
                 "P tot bypass-duct [psia]",
                 "P tot HPC outlet [psia]",
                 "Fan speed [rpm]",
                 "Core speed [rpm]",
                 "Engine pressure ratio",
                 "P static HPC outlet [psia]",
                 "Ratio of fuel flow to Ps30",
                 "Corrected fan speed [rpm]",
                 "Corrected core speed [rpm]",
                 "Bypass ratio",
                 "Burner fuel-air ratio",
                 "Bleed Enthalpy",
                 "Demanded fan speed [rpm]",
                 "Demanded corrected fan speed [rpm]",
                 "HPT oolant bleed [lbm/s]",
                 "LPT coolant [lmb/s]",
                 "RUL"]
DATAS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 265256 entries, 0 to 41213
# Data columns (total 25 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   Parameter 1                         265256 non-null  float64
#  1   Parameter 2                         265256 non-null  float64
#  2   Parameter 3                         265256 non-null  float64
#  3   T° tot fan inlet [°R]               265256 non-null  float64
#  4   T LPC outlet [°R]                   265256 non-null  float64
#  5   T HPC outlet [°R]                   265256 non-null  float64
#  6   T LPT outlet [°R]                   265256 non-null  float64
#  7   P fan inlet [psia]                  265256 non-null  float64
#  8   P tot bypass-duct [psia]            265256 non-null  float64
#  9   P tot HPC outlet [psia]             265256 non-null  float64
#  10  Fan speed [rpm]                     265256 non-null  float64
#  11  Core speed [rpm]                    265256 non-null  float64
#  12  Engine pressure ratio               265256 non-null  float64
#  13  P static HPC outlet [psia]          265256 non-null  float64
#  14  Ratio of fuel flow to Ps30          265256 non-null  float64
#  15  Corrected fan speed [rpm]           265256 non-null  float64
#  16  Corrected core speed [rpm]          265256 non-null  float64
#  17  Bypass ratio                        265256 non-null  float64
#  18  Burner fuel-air ratio               265256 non-null  float64
#  19  Bleed Enthalpy                      265256 non-null  int64
#  20  Demanded fan speed [rpm]            265256 non-null  int64
#  21  Demanded corrected fan speed [rpm]  265256 non-null  float64
#  22  HPT oolant bleed [lbm/s]            265256 non-null  float64
#  23  LPT coolant [lmb/s]                 265256 non-null  float64
#  24  RUL                                 265256 non-null  int64
# dtypes: float64(22), int64(3)
# memory usage: 52.6 MB

# %%
#Tracé des boxplots pour visualiser les outlayers
List_columns = list(DATAS.columns)

plt.boxplot(DATAS["Parameter 1"])
plt.title("Boxplot de Parameter1 ")
plt.show()

plt.boxplot(DATAS["Parameter 2"])
plt.title("Boxplot de Parameter 2 ")
plt.show()

plt.boxplot(DATAS["Parameter 3"])
plt.title("Boxplot de Parameter 3 ")
plt.show()

for i in range(3, 22):
    plt.boxplot(DATAS[List_columns[i]])
    plt.title("Boxplot de " + DATAS.columns[i])
    plt.show()

plt.boxplot(DATAS["RUL"])
plt.title("Boxplot de RUL ")
plt.show()

# %%
#visualisation des distributions pour les boxplots qui semblent bizarre
sns.displot(data=DATAS, x=List_columns[2])
plt.show()

sns.displot(data=DATAS, x=List_columns[10])
plt.show()

sns.displot(data=DATAS, x=List_columns[15])
plt.show()

sns.displot(data=DATAS, x=List_columns[16])
plt.show()

sns.displot(data=DATAS, x=List_columns[17])
plt.show()

sns.displot(data=DATAS, x=List_columns[19])
plt.show()

sns.displot(data=DATAS, x=List_columns[20])
plt.show()

sns.displot(data=DATAS, x="RUL")
plt.show()
